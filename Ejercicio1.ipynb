# %%
import pandas as pd

# %%
datos_usuarios = {
    'ID': [101, 102, 103, 104, 105],
    'nombre': ['Andres Reyes', 'Emmanuel Fernandes', 'Diego Gonzales', 'Ana Morillo', 'Josmary Valero'],
    'correo': [
        'Andersreyes10@gmail.com', 
        'ennanuelfernande@provider.net', 
        'Diegoerggonzales22@webmail.org', 
        'Ana.Morrillo@gmail.com', 
        'fandelonepiece04009@company.com'
    ],
    'calificacion': [18, 14, 19, 17, 15],
    'estado': ['activo', 'inactivo', 'activo', 'activo', 'inactivo']
}

# %%
df_campana = pd.DataFrame(datos_usuarios)

# %%
print("Dataset de usuarios para la Campaña:")
print(df_campana)
# Out:
# Dataset de usuarios para la Campaña:
#     ID              nombre                           correo  calificacion  \
# 0  101        Andres Reyes          Andersreyes10@gmail.com            18
# 1  102  Emmanuel Fernandes    ennanuelfernande@provider.net            14
# 2  103      Diego Gonzales   Diegoerggonzales22@webmail.org            19
# 3  104         Ana Morillo           Ana.Morrillo@gmail.com            17
# 4  105      Josmary Valero  fandelonepiece04009@company.com            15
#
#      estado
# 0    activo
# 1  inactivo
# 2    activo
# 3    activo
# 4  inactivo
